# %% [markdown]
# <div>
# <center><img src="../assets/Flux-logo.svg" width="400"/>
# </div>
#
# # Chapter 2: Python Submission API 🐍️
#
# Flux also provides first-class python bindings which can be used to submit jobs programmatically.

# %% [markdown]
# ### Importing the flux package
#
# Flux requires python to build, so if you have Flux installed, you have at least one python installation that works. However, you can also `pip install flux-python` to get the `flux` package in a side-installation of python (which you may have to do in this notebook!)

# %%
# !python3 -c "import flux; print(flux.Flux())"
# Out:
# <flux.core.handle.Flux object at 0x7fffff023c10>

# %%
import os
import json
import flux
import flux.job
from flux.job import JobspecV1
from flux.job.JobID import JobID

# %% [markdown]
# ### `flux.job.JobspecV1` to create job specifications
#
# Flux represents work as a standard called the [Jobspec](https://flux-framework.readthedocs.io/projects/flux-rfc/en/latest/spec_25.html). While you could write YAML or JSON, it's much easier to use provided Python functions that take high level metadata (command, resources, etc) to generate them. We can then replicate our previous example of submitting multiple heterogeneous jobs using these Python helpers, and testing that Flux co-schedules them.

# %%
# connect to the running Flux instance
f = flux.Flux()

# Create the Jobspec from a command to run a python script, and specify resources
compute_jobreq = JobspecV1.from_command(
    command=["sleep", "5"], num_tasks=1, num_nodes=1, cores_per_task=1
    )
id = flux.job.submit(f, compute_jobreq)

# When we submit, we get back the job identifier (JobID)
print(f'{id.f58 = }')
# Out:
# id.f58 = 'ƒ2LWp7orLX'

# %% [markdown]
# We get a job ID, and the command will _block_ until a job ID is assigned. But, perhaps we want more information about the job, too.

# %%
# Maybe we want a bit more information about this job
info = flux.job.result(f, id)
print(f'{info.to_dict() = }')

rc = info.to_dict()['returncode']
print(rc)


#for i in range(100):
#    flux.job.submit(f, compute_jobreq) # submit and print out the jobid (in f58 format)
# Out:
# info.to_dict() = {'t_run': 1747775966.951468, 't_cleanup': 1747775972.0897667, 'duration': 0.0, 'result': 'COMPLETED', 'waitstatus': 0, 'id': JobID(171149698793472), 't_submit': 1747775966.9232278, 'runtime': 5.138298749923706, 'returncode': 0, 'dependencies': [], 'annotations': {}, 'exception': {'occurred': False}}
# 0

# %% [markdown]
# Once we create the job, when we submit it in Python we get back a job identifier or jobid. We can then interact with the Flux handle, a connection to Flux, to get information about that job.
#
# ### `flux.job.get_job(handle, jobid)` to get job info

# %%
# Let's submit again to retrieve (and save) the job identifier
compute_jobreq = JobspecV1.from_command(
    command=["sleep", "15"], num_tasks=1, num_nodes=1, cores_per_task=1
    )

## Explain how to set environment in Jobspec
# import os, json
# compute_jobreq.environment = json.dumps(os.environ)

fluxjob = flux.job.submit(f, compute_jobreq)
fluxjobid = JobID(fluxjob.f58)
print(f"🎉️ Hooray, we just submitted {fluxjobid}!\n")

# Here is how to get your info. The first argument is the flux handle, then the jobid
jobinfo = flux.job.get_job(f, fluxjobid)
print(jobinfo)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_215/2316349408.py in <cell line: 7>()
#       5
#       6 import os, json
# ----> 7 compute_jobreq.environment = json.dumps(os.environ)
#       8
#       9 fluxjob = flux.job.submit(f, compute_jobreq)
#
# /usr/lib/python3.10/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     229         cls is None and indent is None and separators is None and
#     230         default is None and not sort_keys and not kw):
# --> 231         return _default_encoder.encode(obj)
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# /usr/lib/python3.10/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.10/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/lib/python3.10/json/encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type _Environ is not JSON serializable

# %% [markdown]
# Look at what came from `.get_job()`. It didn't block, but the job isn't complete yet -- that `t_run` is 0, which makes no sense, because the run time should be around 5 seconds. Notice the status is also 'SCHED', meaning that the job is being scheduled,

# %% [markdown]
# You can now run `flux jobs` to see the jobs that we submit from Python.

# %%
# !flux jobs -a --name="compute.py"
# Out:
#        JOBID USER     NAME       ST NTASKS NNODES     TIME INFO
#   ƒ3Xve8ytQF hobbs17  compute.py CD      1      1   3.057s auk108.llnl.gov
#   ƒ3XbeUmZnX hobbs17  compute.py CD      1      1   3.064s auk108.llnl.gov
#   ƒ3XZ6ghANj hobbs17  compute.py CD      1      1   3.049s auk108.llnl.gov
#   ƒ3XJK5pcTR hobbs17  compute.py CD      1      1   3.053s auk108.llnl.gov
#   ƒ3XDstTCum hobbs17  compute.py CD      1      1   3.053s auk108.llnl.gov
#   ƒ3XDsGsW9V hobbs17  compute.py CD      1      1   3.047s auk108.llnl.gov
#   ƒ3XDrdop6s hobbs17  compute.py CD      1      1   3.051s auk108.llnl.gov
#   ƒ3XDqzk84F hobbs17  compute.py CD      1      1   3.053s auk108.llnl.gov
#   ƒ3XDqPARHy hobbs17  compute.py CD      1      1   3.031s auk108.llnl.gov
#   ƒ3XDpk6jFM hobbs17  compute.py CD      1      1   3.029s auk108.llnl.gov
#   ƒ3XDp733Cj hobbs17  compute.py CD      1      1   3.036s auk108.llnl.gov
#   ƒ3XDoVTLST hobbs17  compute.py CD      1      1   3.079s auk108.llnl.gov
#   ƒ3XDkuiayd hobbs17  compute.py CD      1      1   3.086s auk108.llnl.gov
#   ƒ3XDnpuf7V hobbs17  compute.py CD      1      1   3.084s auk108.llnl.gov
#   ƒ3XDnBqy4s hobbs17  compute.py CD      1      1   3.084s auk108.llnl.gov
#   ƒ3XDmYnH2F hobbs17  compute.py CD      1      1   3.083s auk108.llnl.gov
#   ƒ3XDkFAuef hobbs17  compute.py CD      1      1   3.085s auk108.llnl.gov
#   ƒ3XDizXWqm hobbs17  compute.py CD      1      1   3.066s auk108.llnl.gov
#   ƒ3XDjdbCtP hobbs17  compute.py CD      1      1   3.061s auk108.llnl.gov
#   ƒ3XDh6pRzF hobbs17  compute.py CD      1      1   3.065s auk108.llnl.gov
#   ƒ3XDgTkjwd hobbs17  compute.py CD      1      1   3.068s auk108.llnl.gov
#   ƒ3XDiMTpo9 hobbs17  compute.py CD      1      1   3.060s auk108.llnl.gov
#   ƒ3XDhjt82s hobbs17  compute.py CD      1      1   3.049s auk108.llnl.gov
#   ƒ3XDfrB3BM hobbs17  compute.py CD      1      1   3.053s auk108.llnl.gov
#   ƒ3XDfD7M8j hobbs17  compute.py CD      1      1   3.031s auk108.llnl.gov
#   ƒ3XDea3f67 hobbs17  compute.py CD      1      1   3.033s auk108.llnl.gov
#   ƒ3XDdvyy3V hobbs17  compute.py CD      1      1   3.032s auk108.llnl.gov
#   ƒ3XDYsSRFD hobbs17  compute.py CD      1      1   3.102s auk108.llnl.gov
#   ƒ3XDXbK39y hobbs17  compute.py CD      1      1   3.107s auk108.llnl.gov
#   ƒ3XDYFriUw hobbs17  compute.py CD      1      1   3.105s auk108.llnl.gov
#   ƒ3XDam9W6j hobbs17  compute.py CD      1      1   3.082s auk108.llnl.gov
#   ƒ3XDWxFM7M hobbs17  compute.py CD      1      1   3.108s auk108.llnl.gov
#   ƒ3XDa9ZoLT hobbs17  compute.py CD      1      1   3.086s auk108.llnl.gov
#   ƒ3XDdHvGzs hobbs17  compute.py CD      1      1   3.052s auk108.llnl.gov
#   ƒ3XDceraxF hobbs17  compute.py CD      1      1   3.062s auk108.llnl.gov
#   ƒ3XDc3GtBy hobbs17  compute.py CD      1      1   3.062s auk108.llnl.gov
#   ƒ3XDbQDC9M hobbs17  compute.py CD      1      1   3.075s auk108.llnl.gov
#   ƒ3XDWKBf4j hobbs17  compute.py CD      1      1   3.106s auk108.llnl.gov
#   ƒ3XDVhbxJT hobbs17  compute.py CD      1      1   3.086s auk108.llnl.gov
#   ƒ3XDZXz6aB hobbs17  compute.py CD      1      1   3.068s auk108.llnl.gov
#   ƒ3XDV62FYB hobbs17  compute.py CD      1      1   3.035s auk108.llnl.gov
#   ƒ3XDUSxZVZ hobbs17  compute.py CD      1      1   3.044s auk108.llnl.gov
#   ƒ3XDTotsSw hobbs17  compute.py CD      1      1   3.055s auk108.llnl.gov
#   ƒ3XDTAqBQK hobbs17  compute.py CD      1      1   3.030s auk108.llnl.gov
#   ƒ3XDSZFUe3 hobbs17  compute.py CD      1      1   3.035s auk108.llnl.gov
#   ƒ3XDRvBnbR hobbs17  compute.py CD      1      1   3.041s auk108.llnl.gov
#   ƒ3XDQe4QWB hobbs17  compute.py CD      1      1   3.052s auk108.llnl.gov
#   ƒ3XDRH86Yo hobbs17  compute.py CD      1      1   3.027s auk108.llnl.gov
#   ƒ3XDPMw2Qw hobbs17  compute.py CD      1      1   3.071s auk108.llnl.gov
#   ƒ3XDQ2Uhju hobbs17  compute.py CD      1      1   3.048s auk108.llnl.gov
#   ƒ3XDLqAFWo hobbs17  compute.py CD      1      1   3.104s auk108.llnl.gov
#   ƒ3XDNisLNK hobbs17  compute.py CD      1      1   3.084s auk108.llnl.gov
#   ƒ3XDN5oeKh hobbs17  compute.py CD      1      1   3.084s auk108.llnl.gov
#   ƒ3XDMUDwZR hobbs17  compute.py CD      1      1   3.102s auk108.llnl.gov
#   ƒ3XDLC6ZUB hobbs17  compute.py CD      1      1   3.099s auk108.llnl.gov
#   ƒ3XDKaWrhu hobbs17  compute.py CD      1      1   3.101s auk108.llnl.gov
#   ƒ3XDJwTAfH hobbs17  compute.py CD      1      1   3.032s auk108.llnl.gov
#   ƒ3XDJJPUcf hobbs17  compute.py CD      1      1   3.037s auk108.llnl.gov
#   ƒ3XDHfKna3 hobbs17  compute.py CD      1      1   3.048s auk108.llnl.gov
#   ƒ3XDGzn7F5 hobbs17  compute.py CD      1      1   3.028s auk108.llnl.gov
#   ƒ3XDGLERv7 hobbs17  compute.py CD      1      1   3.026s auk108.llnl.gov
#   ƒ3XDFhAjsV hobbs17  compute.py CD      1      1   3.026s auk108.llnl.gov
#   ƒ3XDF5b37D hobbs17  compute.py CD      1      1   3.036s auk108.llnl.gov
#   ƒ3XDDpweJK hobbs17  compute.py CD      1      1   3.045s auk108.llnl.gov
#   ƒ3XDESXM4b hobbs17  compute.py CD      1      1   3.035s auk108.llnl.gov
#   ƒ3XDDBsxFh hobbs17  compute.py CD      1      1   3.045s auk108.llnl.gov
#   ƒ3XDCYpGD5 hobbs17  compute.py CD      1      1   3.042s auk108.llnl.gov
#   ƒ3XDBwEZSo hobbs17  compute.py CD      1      1   3.046s auk108.llnl.gov
#   ƒ3XDBGgt7q hobbs17  compute.py CD      1      1   3.055s auk108.llnl.gov
#   ƒ3XDAc9Cns hobbs17  compute.py CD      1      1   3.063s auk108.llnl.gov
#   ƒ3XD9wbXTu hobbs17  compute.py CD      1      1   3.068s auk108.llnl.gov
#   ƒ3XD9JXqRH hobbs17  compute.py CD      1      1   3.070s auk108.llnl.gov
#   ƒ3XD8gx8f1 hobbs17  compute.py CD      1      1   3.027s auk108.llnl.gov
#   ƒ3XD83tScP hobbs17  compute.py CD      1      1   3.030s auk108.llnl.gov
#   ƒ3XD7QpkZm hobbs17  compute.py CD      1      1   3.033s auk108.llnl.gov
#   ƒ3XD6oF3oV hobbs17  compute.py CD      1      1   3.027s auk108.llnl.gov
#   ƒ3XD6ABMks hobbs17  compute.py CD      1      1   3.024s auk108.llnl.gov
#   ƒ3XD5Ybezb hobbs17  compute.py CD      1      1   3.028s auk108.llnl.gov
#   ƒ3XD4uXxwy hobbs17  compute.py CD      1      1   3.035s auk108.llnl.gov
#   ƒ3XD4GUGuM hobbs17  compute.py CD      1      1   3.026s auk108.llnl.gov
#   ƒ3XD3dQarj hobbs17  compute.py CD      1      1   3.036s auk108.llnl.gov
#   ƒ3XD2zLtp7 hobbs17  compute.py CD      1      1   3.036s auk108.llnl.gov
#   ƒ3XD2NmC3q hobbs17  compute.py CD      1      1   3.036s auk108.llnl.gov
#   ƒ3XD1mBVHZ hobbs17  compute.py CD      1      1   3.046s auk108.llnl.gov
#   ƒ3XD187oEw hobbs17  compute.py CD      1      1   3.043s auk108.llnl.gov
#   ƒ3XCzWY6Uf hobbs17  compute.py CD      1      1   3.044s auk108.llnl.gov
#   ƒ3XCytxPiP hobbs17  compute.py CD      1      1   3.054s auk108.llnl.gov
#   ƒ3XCyJrgET hobbs17  compute.py CD      1      1   3.062s auk108.llnl.gov
#   ƒ3XCxkEx2s hobbs17  compute.py CD      1      1   3.030s auk108.llnl.gov
#   ƒ3XCx8fFGb hobbs17  compute.py CD      1      1   3.029s auk108.llnl.gov
#   ƒ3XCwa3X51 hobbs17  compute.py CD      1      1   3.034s auk108.llnl.gov
#   ƒ3XCw1RnsR hobbs17  compute.py CD      1      1   3.027s auk108.llnl.gov
#   ƒ3XCvUJ3xB hobbs17  compute.py CD      1      1   3.030s auk108.llnl.gov
#   ƒ3XCutCLUF hobbs17  compute.py CD      1      1   3.031s auk108.llnl.gov
#   ƒ3XCuM4bZ1 hobbs17  compute.py CD      1      1   3.030s auk108.llnl.gov
#   ƒ3XCtnSsMR hobbs17  compute.py CD      1      1   3.026s auk108.llnl.gov
#   ƒ3XCtFK8SB hobbs17  compute.py CD      1      1   3.035s auk108.llnl.gov
#   ƒ3XCsghQEb hobbs17  compute.py CD      1      1   3.036s auk108.llnl.gov
#   ƒ3XCs85g31 hobbs17  compute.py CD      1      1   3.036s auk108.llnl.gov
#   ƒ3XCrZTwqR hobbs17  compute.py CD      1      1   3.035s auk108.llnl.gov
#   ƒ3XCqzrDdq hobbs17  compute.py CD      1      1   3.037s auk108.llnl.gov
#   ƒ3XCqTiUib hobbs17  compute.py CD      1      1   3.042s auk108.llnl.gov
#   ƒ3XCpr8mxK hobbs17  compute.py CD      1      1   3.044s auk108.llnl.gov
#   ƒ3XCpG34UP hobbs17  compute.py CD      1      1   3.062s auk108.llnl.gov
#   ƒ3WKTBrDfm hobbs17  compute.py CA      1      1   30.52s auk108.llnl.gov
#   ƒ3WKUpjRhq hobbs17  compute.py CA      1      1   30.45s auk108.llnl.gov
#   ƒ3WKSdEVUB hobbs17  compute.py CA      1      1   30.54s auk108.llnl.gov
#   ƒ3WKMe8uWw hobbs17  compute.py CA      1      1   30.73s auk108.llnl.gov
#   ƒ3WKRXV2MM hobbs17  compute.py CA      1      1   30.58s auk108.llnl.gov
#   ƒ3WKPtbpKH hobbs17  compute.py CA      1      1   30.64s auk108.llnl.gov
#   ƒ3WKVQq9Bm hobbs17  compute.py CA      1      1   11.88s auk108.llnl.gov
#   ƒ3WKNnrMCT hobbs17  compute.py CA      1      1   30.69s auk108.llnl.gov
#   ƒ3WKQRjZEX hobbs17  compute.py CA      1      1   30.62s auk108.llnl.gov
#   ƒ3WKS4cmGb hobbs17  compute.py CA      1      1   30.56s auk108.llnl.gov
#   ƒ3W3m5q6vB hobbs17  compute.py CA      1      1   1.102m auk108.llnl.gov
#   ƒ3WKPKz67h hobbs17  compute.py CA      1      1   30.66s auk108.llnl.gov
#   ƒ3WKQxsJ9m hobbs17  compute.py CA      1      1    30.6s auk108.llnl.gov
#   ƒ3WKNEEczs hobbs17  compute.py CA      1      1   30.71s auk108.llnl.gov
#   ƒ3WKTkTwsM hobbs17  compute.py CA      1      1   30.49s auk108.llnl.gov
#   ƒ3WKUHbgnb hobbs17  compute.py CA      1      1   30.47s auk108.llnl.gov
#   ƒ3WKaxYTLb hobbs17  compute.py CA      1      1        -
#   ƒ3WKba8A6s hobbs17  compute.py CA      1      1        -
#   ƒ3WKcBhrs9 hobbs17  compute.py CA      1      1        -
#   ƒ3WKcoHZdR hobbs17  compute.py CA      1      1        -
#   ƒ3WLDqrazB hobbs17  compute.py CA      1      1        -
#   ƒ3WKdQsGPh hobbs17  compute.py CA      1      1        -
#   ƒ3WPEFG6kw hobbs17  compute.py CA      1      1        -
#   ƒ3WKpTKv8f hobbs17  compute.py CA      1      1        -
#   ƒ3WKq4uctw hobbs17  compute.py CA      1      1        -
#   ƒ3WKqgVKfD hobbs17  compute.py CA      1      1        -
#   ƒ3WNpesXef hobbs17  compute.py CA      1      1        -
#   ƒ3WKrJ52RV hobbs17  compute.py CA      1      1        -
#   ƒ3WKvb8wmR hobbs17  compute.py CA      1      1        -
#   ƒ3WKwCieXh hobbs17  compute.py CA      1      1        -
#   ƒ3WKwpJMHy hobbs17  compute.py CA      1      1        -
#   ƒ3WPXdPgPR hobbs17  compute.py CA      1      1        -
#   ƒ3WNwc8AJT hobbs17  compute.py CA      1      1        -
#   ƒ3WNxDhs4j hobbs17  compute.py CA      1      1        -
#   ƒ3WNxqHZq1 hobbs17  compute.py CA      1      1        -
#   ƒ3WL3LXgAT hobbs17  compute.py CA      1      1        -
#   ƒ3WL3x7Nvj hobbs17  compute.py CA      1      1        -
#   ƒ3WL5nrVDZ hobbs17  compute.py CA      1      1        -
#   ƒ3WKVySsPM hobbs17  compute.py CA      1      1        -
#   ƒ3WKXCcGuu hobbs17  compute.py CA      1      1        -
#   ƒ3WKXpBygB hobbs17  compute.py CA      1      1        -
#   ƒ3WP7RRQWs hobbs17  compute.py CA      1      1        -
#   ƒ3WP8eap3R hobbs17  compute.py CA      1      1        -
#   ƒ3WP9GAWoh hobbs17  compute.py CA      1      1        -
#   ƒ3WP9skDZy hobbs17  compute.py CA      1      1        -
#   ƒ3WPAVKvLF hobbs17  compute.py CA      1      1        -
#   ƒ3WLBvfWrK hobbs17  compute.py CA      1      1        -
#   ƒ3WNaU4QFH hobbs17  compute.py CA      1      1        -
#   ƒ3WLJsv9W7 hobbs17  compute.py CA      1      1        -
#   ƒ3WLL75Z2f hobbs17  compute.py CA      1      1        -
#   ƒ3WLLifFnw hobbs17  compute.py CA      1      1        -
#   ƒ3WLMLExZD hobbs17  compute.py CA      1      1        -
#   ƒ3WPSeJ6SB hobbs17  compute.py CA      1      1        -
#   ƒ3WNtTmge3 hobbs17  compute.py CA      1      1        -
#   ƒ3WNu5MPQK hobbs17  compute.py CA      1      1        -
#   ƒ3WNcqwFTM hobbs17  compute.py CA      1      1        -
#   ƒ3WLF7yy5R hobbs17  compute.py CA      1      1        -
#   ƒ3WNdTWxDd hobbs17  compute.py CA      1      1        -
#   ƒ3WLFjZfqh hobbs17  compute.py CA      1      1        -
#   ƒ3WNe56eyu hobbs17  compute.py CA      1      1        -
#   ƒ3WNeggMkB hobbs17  compute.py CA      1      1        -
#   ƒ3WNfJG4WT hobbs17  compute.py CA      1      1        -
#   ƒ3WNfuqmGj hobbs17  compute.py CA      1      1        -
#   ƒ3WPGkYtNj hobbs17  compute.py CA      1      1        -
#   ƒ3WNgXRU31 hobbs17  compute.py CA      1      1        -
#   ƒ3WPHN8b91 hobbs17  compute.py CA      1      1        -
#   ƒ3WNh91AoH hobbs17  compute.py CA      1      1        -
#   ƒ3WPHyiHuH hobbs17  compute.py CA      1      1        -
#   ƒ3WNhkasZZ hobbs17  compute.py CA      1      1        -
#   ƒ3WPJbHzfZ hobbs17  compute.py CA      1      1        -
#   ƒ3WPKCshRq hobbs17  compute.py CA      1      1        -
#   ƒ3WKkpog7h hobbs17  compute.py CA      1      1        -
#   ƒ3WKmSPNsy hobbs17  compute.py CA      1      1        -
#   ƒ3WKn3y5eF hobbs17  compute.py CA      1      1        -
#   ƒ3WKnfYnQX hobbs17  compute.py CA      1      1        -
#   ƒ3WPNtMv1V hobbs17  compute.py CA      1      1        -
#   ƒ3WPPVwcmm hobbs17  compute.py CA      1      1        -
#   ƒ3WPQ7XKY3 hobbs17  compute.py CA      1      1        -
#   ƒ3WPYHwMiP hobbs17  compute.py CA      1      1        -
#   ƒ3WPYuX4Uf hobbs17  compute.py CA      1      1        -
#   ƒ3WPZX6mEw hobbs17  compute.py CA      1      1        -
#   ƒ3WPa8gU1D hobbs17  compute.py CA      1      1        -
#   ƒ3WL1YkYSK hobbs17  compute.py CA      1      1        -
#   ƒ3WL2ALFCb hobbs17  compute.py CA      1      1        -
#   ƒ3WL2muwxs hobbs17  compute.py CA      1      1        -
#   ƒ3WP3nuAVu hobbs17  compute.py CA      1      1        -
#   ƒ3WP4QUsGB hobbs17  compute.py CA      1      1        -
#   ƒ3WKYUjf19 hobbs17  compute.py CA      1      1        -
#   ƒ3WKZ6KMmR hobbs17  compute.py CA      1      1        -
#   ƒ3WKZhu4Xh hobbs17  compute.py CA      1      1        -
#   ƒ3WKaKUmHy hobbs17  compute.py CA      1      1        -
#   ƒ3WLDCntwZ hobbs17  compute.py CA      1      1        -
#   ƒ3WPCP31Bm hobbs17  compute.py CA      1      1        -
#   ƒ3WPCzchx3 hobbs17  compute.py CA      1      1        -
#   ƒ3WPDcCQiK hobbs17  compute.py CA      1      1        -
#   ƒ3WLMzndtB hobbs17  compute.py CA      1      1        -
#   ƒ3WLPqXkB1 hobbs17  compute.py CA      1      1        -
#   ƒ3WNp1oqc3 hobbs17  compute.py CA      1      1        -
#   ƒ3WPV9at3y hobbs17  compute.py CA      1      1        -
#   ƒ3WPVmAapF hobbs17  compute.py CA      1      1        -
#   ƒ3WPWNkHaX hobbs17  compute.py CA      1      1        -
#   ƒ3WPWzKzLo hobbs17  compute.py CA      1      1        -
#   ƒ3WNvy4UFq hobbs17  compute.py CA      1      1        -
#   ƒ3WL4YD6Qf hobbs17  compute.py CA      1      1        -
#   ƒ3WPdwaczb hobbs17  compute.py CA      1      1        -
#   ƒ3WL59noAw hobbs17  compute.py CA      1      1        -
#   ƒ3WKWZYasH hobbs17  compute.py CA      1      1        -
#   ƒ3WLH1h3vw hobbs17  compute.py CA      1      1        -
#   ƒ3WLHdGkhD hobbs17  compute.py CA      1      1        -
#   ƒ3WLJErTTV hobbs17  compute.py CA      1      1        -
#   ƒ3WLKU1rz3 hobbs17  compute.py CA      1      1        -
#   ƒ3WNj2iFeo hobbs17  compute.py CA      1      1        -
#   ƒ3WNjeHxR5 hobbs17  compute.py CA      1      1        -
#   ƒ3WNoKnAzj hobbs17  compute.py CA      1      1        -
#   ƒ3WPS1EQPZ hobbs17  compute.py CA      1      1        -
#   ƒ3WNsD8Hq9 hobbs17  compute.py CA      1      1        -
#   ƒ3WNsphzbR hobbs17  compute.py CA      1      1        -
#   ƒ3WPc2PYrj hobbs17  compute.py CA      1      1        -
#   ƒ3WPcdyFd1 hobbs17  compute.py CA      1      1        -
#   ƒ3WLEUvH2o hobbs17  compute.py CA      1      1        -
#   ƒ3WKe3vxSK hobbs17  compute.py CA      1      1        -
#   ƒ3WKefWfCb hobbs17  compute.py CA      1      1        -
#   ƒ3WKfH6Mxs hobbs17  compute.py CA      1      1        -
#   ƒ3WPEtKnoZ hobbs17  compute.py CA      1      1        -
#   ƒ3WKftg4j9 hobbs17  compute.py CA      1      1        -
#   ƒ3WPFVuVZq hobbs17  compute.py CA      1      1        -
#   ƒ3WKgWFmVR hobbs17  compute.py CA      1      1        -
#   ƒ3WPG7VCL7 hobbs17  compute.py CA      1      1        -
#   ƒ3WKh7qUFh hobbs17  compute.py CA      1      1        -
#   ƒ3WKhjRB1y hobbs17  compute.py CA      1      1        -
#   ƒ3WKiLzsnF hobbs17  compute.py CA      1      1        -
#   ƒ3WKixaaYX hobbs17  compute.py CA      1      1        -
#   ƒ3WKjaAHJo hobbs17  compute.py CA      1      1        -
#   ƒ3WKkBjz55 hobbs17  compute.py CA      1      1        -
#   ƒ3WPKnyQum hobbs17  compute.py CA      1      1        -
#   ƒ3WPLQZ7g3 hobbs17  compute.py CA      1      1        -
#   ƒ3WPM28pSK hobbs17  compute.py CA      1      1        -
#   ƒ3WPMdiXCb hobbs17  compute.py CA      1      1        -
#   ƒ3WPNFJDxs hobbs17  compute.py CA      1      1        -
#   ƒ3WKoFeVtT hobbs17  compute.py CA      1      1        -
#   ƒ3WKosECej hobbs17  compute.py CA      1      1        -
#   ƒ3WNqHwDhH hobbs17  compute.py CA      1      1        -
#   ƒ3WKrw8iU7 hobbs17  compute.py CA      1      1        -
#   ƒ3WNquWvTZ hobbs17  compute.py CA      1      1        -
#   ƒ3WKsYiREP hobbs17  compute.py CA      1      1        -
#   ƒ3WKtAJ7zf hobbs17  compute.py CA      1      1        -
#   ƒ3WKtmspkw hobbs17  compute.py CA      1      1        -
#   ƒ3WKuPTXXD hobbs17  compute.py CA      1      1        -
#   ƒ3WKv13EHV hobbs17  compute.py CA      1      1        -
#   ƒ3WKxTN3Lb hobbs17  compute.py CA      1      1        -
#   ƒ3WKy4wk6s hobbs17  compute.py CA      1      1        -
#   ƒ3WKygXSs9 hobbs17  compute.py CA      1      1        -
#   ƒ3WKzJ79dR hobbs17  compute.py CA      1      1        -
#   ƒ3WNyUMFsd hobbs17  compute.py CA      1      1        -
#   ƒ3WKzugrPh hobbs17  compute.py CA      1      1        -
#   ƒ3WNz5vxdu hobbs17  compute.py CA      1      1        -
#   ƒ3WNzhWfQB hobbs17  compute.py CA      1      1        -
#   ƒ3WP1K6NAT hobbs17  compute.py CA      1      1        -
#   ƒ3WP1vg4vj hobbs17  compute.py CA      1      1        -
#   ƒ3WP2YFmh1 hobbs17  compute.py CA      1      1        -
#   ƒ3WP39qUTH hobbs17  compute.py CA      1      1        -
#   ƒ3WP4zaak7 hobbs17  compute.py CA      1      1        -
#   ƒ3WL6RvBGB hobbs17  compute.py CA      1      1        -
#   ƒ3WP5cAHWP hobbs17  compute.py CA      1      1        -
#   ƒ3WL73Vt2T hobbs17  compute.py CA      1      1        -
#   ƒ3WP6DjzGf hobbs17  compute.py CA      1      1        -
#   ƒ3WL7f5anj hobbs17  compute.py CA      1      1        -
#   ƒ3WP6qKh2w hobbs17  compute.py CA      1      1        -
#   ƒ3WL8GfHZ1 hobbs17  compute.py CA      1      1        -
#   ƒ3WL8tEzKH hobbs17  compute.py CA      1      1        -
#   ƒ3WP84V6ZV hobbs17  compute.py CA      1      1        -
#   ƒ3WL9Vph5Z hobbs17  compute.py CA      1      1        -
#   ƒ3WLA7QPqq hobbs17  compute.py CA      1      1        -
#   ƒ3WLAiz6c7 hobbs17  compute.py CA      1      1        -
#   ƒ3WLBLZoNP hobbs17  compute.py CA      1      1        -
#   ƒ3WPB8PcNs hobbs17  compute.py CA      1      1        -
#   ƒ3WLCZjCtw hobbs17  compute.py CA      1      1        -
#   ƒ3WPBjyK99 hobbs17  compute.py CA      1      1        -
#   ƒ3WLNatMN7 hobbs17  compute.py CA      1      1        -
#   ƒ3WLPCU48P hobbs17  compute.py CA      1      1        -
#   ƒ3WPTHMnUo hobbs17  compute.py CA      1      1        -
#   ƒ3WPTtwVF5 hobbs17  compute.py CA      1      1        -
#   ƒ3WPUWXC1M hobbs17  compute.py CA      1      1        -
#   ƒ3WNuiR5Sw hobbs17  compute.py CA      1      1        -
#   ƒ3WNvKznDD hobbs17  compute.py CA      1      1        -
#   ƒ3WPdJWvwy hobbs17  compute.py CA      1      1        -
#   ƒ3WNb2g8Ss hobbs17  compute.py CA      1      1        -
#   ƒ3WNbeFqD9 hobbs17  compute.py CA      1      1        -
#   ƒ3WNcFqXyR hobbs17  compute.py CA      1      1        -
#   ƒ3WLGNdMtK hobbs17  compute.py CA      1      1        -
#   ƒ3WNiPeZcB hobbs17  compute.py CA      1      1        -
#   ƒ3WNkEPfu1 hobbs17  compute.py CA      1      1        -
#   ƒ3WNkqyNfH hobbs17  compute.py CA      1      1        -
#   ƒ3WNmTZ5RZ hobbs17  compute.py CA      1      1        -
#   ƒ3WNn58nBq hobbs17  compute.py CA      1      1        -
#   ƒ3WNngiUx7 hobbs17  compute.py CA      1      1        -
#   ƒ3WPQkb1af hobbs17  compute.py CA      1      1        -
#   ƒ3WPRNAiLw hobbs17  compute.py CA      1      1        -
#   ƒ3WNra4bnX hobbs17  compute.py CA      1      1        -
#   ƒ3WPamkA3q hobbs17  compute.py CA      1      1        -
#   ƒ3WPbPKrp7 hobbs17  compute.py CA      1      1        -
#   ƒ3VYhZKdFu hobbs17  compute.py CD      1      1   2.003m auk108.llnl.gov
#   ƒ3S2Tqt57V hobbs17  compute.py CD      1      1   2.001m auk108.llnl.gov
#   ƒ3Ru5fmVZH hobbs17  compute.py CD      1      1   2.003m auk108.llnl.gov

# %% [markdown]
# Under the hood, the `Jobspec` class is creating a YAML document that ultimately gets serialized as JSON and sent to Flux for ingestion, validation, queueing, scheduling, and eventually execution.  We can dump the raw JSON jobspec that is submitted, where we can see the exact resources requested and the task set to be executed on those resources.

# %%
print(compute_jobreq.dumps(indent=2))
# Out:
# {
#   "resources": [
#     {
#       "type": "node",
#       "count": 1,
#       "with": [
#         {
#           "type": "slot",
#           "count": 1,
#           "with": [
#             {
#               "type": "core",
#               "count": 1
#             }
#           ],
#           "label": "task"
#         }
#       ]
#     }
#   ],
#   "tasks": [
#     {
#       "command": [
#         "sleep",
#         "15"
#       ],
#       "slot": "task",
#       "count": {
#         "per_slot": 1
#       }
#     }
#   ],
#   "attributes": {
#     "system": {
#       "duration": 0
#     }
#   },
#   "version": 1
# }

# %% [markdown]
# ### Playing with the Synchronous job submission API

# %%
    handle = flux.Flux()
    jobspec = JobspecV1.from_command(
        command=["sleep", "0"], num_tasks=4, num_nodes=1,
    )
    jobspec.cwd = os.getcwd()
    jobspec.exclusive=1
    jobspec.t=5
    jobspec.environment = dict(os.environ)
    jobspec.setattr("
    jobspec.stdout="PYEXAMPLE.{{id}}.out"
    jobspec.stderr="PYEXAMPLE.{{id}}.err"
    id = flux.job.submit(handle, jobspec)

###
info = flux.job.event_wait(handle, id, "start")
## fetch the R, give you a nodelist
print(info)
# Out:
# 1747777754.06953: start {}

# %% [markdown]
# ### `FluxExecutor` for bulk submission
#
# We can use the FluxExecutor class to submit large numbers of jobs to Flux. This method resembles python's `concurrent.futures` interface.

# %%
from flux.job import FluxExecutor
with FluxExecutor() as executor:
    compute_jobspec = JobspecV1.from_command(["sleep", "3"])
    futures = [executor.submit(compute_jobspec) for _ in range(10)]
    # wait for the jobid for each job, as a proxy for the job being submitted
    executor.shutdown(wait=False)

compute_jobspec = JobspecV1.from_command(["sleep", "3"])

# all jobs submitted - print timings
print("I'm all done")
# Out:
# I'm all done

# %%
# Submit the FluxExecutor based script.
# !flux python bulksubmit_executor.py -n200 /bin/sleep 0
# Out:
# bulksubmit_executor: submitted 200 jobs in 0.11s. 1785.83job/s
# bulksubmit_executor: First job finished in about 0.177s
# |██████████████████████████████████████████████████████████| 100.0% (286.2 job/s)
# bulksubmit_executor: Ran 200 jobs in 0.9s. 221.7 job/s

# %%
import concurrent.futures
import flux.job

jobspec = flux.job.JobspecV1.from_command(["/bin/true"])
with flux.job.FluxExecutor() as executor:
        futs = [executor.submit(jobspec) for _ in range(5)]
        for f in concurrent.futures.as_completed(futs):
                print(f.result())
# Out:
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# ### `flux.event_watch` to watch events
#
# If you want to get the output of a job (or more generally, stream events) you can do that as follows. Let's submit a quick job, and then look at the output.

# %%
# Create the Jobspec from a command to run a python script, and specify resources
f = flux.Flux()
jobspec = JobspecV1.from_nest_command(
    command=["echo", "Flux Plumbing 💩️🚽️"], conf={"resource": {"rediscover": True}})
jobspec.setattr("system.gpumode", "GPX")
jobid = flux.job.submit(f, jobspec)

flux.job.event_wait(f, jobid, "finish")

for line in flux.job.event_watch(f, jobid, "guest.output"):
    print(line)
# Out:
# 1747778552.58787: header {'version': 1, 'encoding': {'stdout': 'UTF-8', 'stderr': 'UTF-8'}, 'count': {'stdout': 1, 'stderr': 1}, 'options': {}}
# 1747778554.12472: data {'stream': 'stdout', 'rank': '0', 'data': 'Flux Plumbing 💩️🚽️\n'}
# 1747778556.06424: data {'stream': 'stderr', 'rank': '0', 'eof': True}
# 1747778556.06431: data {'stream': 'stdout', 'rank': '0', 'eof': True}

# %% [markdown]
# ### `flux.job.job_list` to list jobs
#
# Finally, it can be really helpful to get an entire listing of jobs. You can do that as follows. Note that the `job_list` is creating a remote procedure call (rpc) and we call `get` to retrieve the output.

# %%
flux.job.job_list(f).get()
# Out:
# {'jobs': [{'id': 204189070262272,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777936.2329323,
#    't_depend': 1747777936.2466457,
#    't_run': 1747777936.2605789,
#    't_cleanup': 1747777936.37797,
#    't_inactive': 1747777936.3798347,
#    'state': 64,
#    'name': 'echo',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 203393897332736,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777888.8370345,
#    't_depend': 1747777888.8494458,
#    't_run': 1747777888.8638089,
#    't_cleanup': 1747777888.9835453,
#    't_inactive': 1747777888.9857152,
#    'state': 64,
#    'name': 'echo',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 201132345393152,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777754.037007,
#    't_depend': 1747777754.0504465,
#    't_run': 1747777754.065451,
#    't_cleanup': 1747777754.2059205,
#    't_inactive': 1747777754.2084167,
#    'state': 64,
#    'name': 'sleep',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 4,
#    'ncores': 4,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 200753582964736,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777731.460739,
#    't_depend': 1747777731.4755652,
#    't_run': 1747777731.4894578,
#    't_cleanup': 1747777731.6271572,
#    't_inactive': 1747777731.6292787,
#    'state': 64,
#    'name': 'sleep',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 4,
#    'ncores': 4,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 200494945402880,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777716.0449507,
#    't_depend': 1747777716.0579896,
#    't_run': 1747777716.0732927,
#    't_cleanup': 1747777716.1740532,
#    't_inactive': 1747777716.1798818,
#    'state': 64,
#    'name': 'a.out',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 4,
#    'ncores': 4,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'exec',
#    'exception_severity': 0,
#    'exception_note': 'task 0 (host 248eca26e3ad): start failed: ./a.out: No such file or directory',
#    'result': 2,
#    'expiration': 9223372036.0,
#    'waitstatus': 32512},
#   {'id': 193632594296833,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777307.014397,
#    't_depend': 1747777307.0336444,
#    't_run': 1747777307.0552368,
#    't_cleanup': 1747777310.250215,
#    't_inactive': 1747777310.2544599,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 193632594296834,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777307.0145257,
#    't_depend': 1747777307.0336955,
#    't_run': 1747777307.055293,
#    't_cleanup': 1747777310.248953,
#    't_inactive': 1747777310.2512767,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 193632594296832,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777307.014239,
#    't_depend': 1747777307.0335922,
#    't_run': 1747777307.0551658,
#    't_cleanup': 1747777310.2439137,
#    't_inactive': 1747777310.2487957,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 193632577519620,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777307.0139267,
#    't_depend': 1747777307.033487,
#    't_run': 1747777307.0550482,
#    't_cleanup': 1747777310.243444,
#    't_inactive': 1747777310.248259,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 193632577519621,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777307.014051,
#    't_depend': 1747777307.0335398,
#    't_run': 1747777307.055103,
#    't_cleanup': 1747777310.2410235,
#    't_inactive': 1747777310.247273,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 193632577519619,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777307.0137484,
#    't_depend': 1747777307.0334318,
#    't_run': 1747777307.0549872,
#    't_cleanup': 1747777310.2399528,
#    't_inactive': 1747777310.2459865,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 193632577519618,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777307.0136223,
#    't_depend': 1747777307.033379,
#    't_run': 1747777307.0549083,
#    't_cleanup': 1747777310.2369993,
#    't_inactive': 1747777310.2426581,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 193632577519617,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777307.013451,
#    't_depend': 1747777307.033317,
#    't_run': 1747777307.053935,
#    't_cleanup': 1747777310.236956,
#    't_inactive': 1747777310.2409353,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 193632560742400,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777307.0132227,
#    't_depend': 1747777307.033201,
#    't_run': 1747777307.0525882,
#    't_cleanup': 1747777310.2320523,
#    't_inactive': 1747777310.2368538,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 193632577519616,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777307.013258,
#    't_depend': 1747777307.0332618,
#    't_run': 1747777307.0538573,
#    't_cleanup': 1747777310.229842,
#    't_inactive': 1747777310.233667,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191612114173953,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777186.5839686,
#    't_depend': 1747777186.5969186,
#    't_run': 1747777186.6188483,
#    't_cleanup': 1747777189.809867,
#    't_inactive': 1747777189.8135254,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191612114173952,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777186.5837836,
#    't_depend': 1747777186.5968676,
#    't_run': 1747777186.6182606,
#    't_cleanup': 1747777189.8079965,
#    't_inactive': 1747777189.8131256,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191612097396741,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777186.5835707,
#    't_depend': 1747777186.5968237,
#    't_run': 1747777186.6182017,
#    't_cleanup': 1747777189.8078158,
#    't_inactive': 1747777189.812183,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191612097396739,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777186.5832274,
#    't_depend': 1747777186.5967145,
#    't_run': 1747777186.6180978,
#    't_cleanup': 1747777189.8050508,
#    't_inactive': 1747777189.8110447,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191612097396740,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777186.5833836,
#    't_depend': 1747777186.5967734,
#    't_run': 1747777186.6181483,
#    't_cleanup': 1747777189.8028228,
#    't_inactive': 1747777189.810137,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191612097396738,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777186.583038,
#    't_depend': 1747777186.5966635,
#    't_run': 1747777186.618041,
#    't_cleanup': 1747777189.799221,
#    't_inactive': 1747777189.8069594,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191612097396737,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777186.5828505,
#    't_depend': 1747777186.5966103,
#    't_run': 1747777186.617975,
#    't_cleanup': 1747777189.7991428,
#    't_inactive': 1747777189.8068314,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191612080619521,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777186.5824213,
#    't_depend': 1747777186.5964854,
#    't_run': 1747777186.6166153,
#    't_cleanup': 1747777189.7969255,
#    't_inactive': 1747777189.8051846,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191612097396736,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777186.5826259,
#    't_depend': 1747777186.5965407,
#    't_run': 1747777186.6179016,
#    't_cleanup': 1747777189.7968347,
#    't_inactive': 1747777189.8043935,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191612080619520,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777186.5820463,
#    't_depend': 1747777186.5964293,
#    't_run': 1747777186.6153197,
#    't_cleanup': 1747777189.7934213,
#    't_inactive': 1747777189.799667,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191439711502340,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777176.3082988,
#    't_depend': 1747777176.3213003,
#    't_run': 1747777176.3412163,
#    't_cleanup': 1747777179.5327053,
#    't_inactive': 1747777179.5357847,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191439711502339,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777176.3081632,
#    't_depend': 1747777176.3212497,
#    't_run': 1747777176.3411634,
#    't_cleanup': 1747777179.5321846,
#    't_inactive': 1747777179.5353951,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191439711502337,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777176.307841,
#    't_depend': 1747777176.321146,
#    't_run': 1747777176.3410602,
#    't_cleanup': 1747777179.5274682,
#    't_inactive': 1747777179.5335402,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191439711502338,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777176.3079958,
#    't_depend': 1747777176.3211985,
#    't_run': 1747777176.341113,
#    't_cleanup': 1747777179.5274005,
#    't_inactive': 1747777179.5334103,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191439694725123,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777176.307354,
#    't_depend': 1747777176.320989,
#    't_run': 1747777176.3408766,
#    't_cleanup': 1747777179.5237186,
#    't_inactive': 1747777179.528933,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191439694725120,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777176.306741,
#    't_depend': 1747777176.3208187,
#    't_run': 1747777176.3383012,
#    't_cleanup': 1747777179.5236802,
#    't_inactive': 1747777179.5287778,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191439694725122,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777176.3071485,
#    't_depend': 1747777176.3209367,
#    't_run': 1747777176.3396444,
#    't_cleanup': 1747777179.5226395,
#    't_inactive': 1747777179.5282438,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191439711502336,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777176.3076894,
#    't_depend': 1747777176.3210948,
#    't_run': 1747777176.341005,
#    't_cleanup': 1747777179.518129,
#    't_inactive': 1747777179.5251203,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191439694725121,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777176.3069513,
#    't_depend': 1747777176.3208797,
#    't_run': 1747777176.3395426,
#    't_cleanup': 1747777179.5178137,
#    't_inactive': 1747777179.524752,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 191439694725124,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777176.307518,
#    't_depend': 1747777176.321042,
#    't_run': 1747777176.3409445,
#    't_cleanup': 1747777179.5175557,
#    't_inactive': 1747777179.523557,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 190956326354947,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777147.496375,
#    't_depend': 1747777147.5134077,
#    't_run': 1747777147.5312536,
#    't_cleanup': 1747777147.6650338,
#    't_inactive': 1747777147.6669717,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 190956326354948,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777147.496543,
#    't_depend': 1747777147.5134563,
#    't_run': 1747777147.5319393,
#    't_cleanup': 1747777147.6630874,
#    't_inactive': 1747777147.6651485,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 190956326354946,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777147.4961922,
#    't_depend': 1747777147.5133586,
#    't_run': 1747777147.5311925,
#    't_cleanup': 1747777147.6600463,
#    't_inactive': 1747777147.6622152,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 190956326354945,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777147.4959683,
#    't_depend': 1747777147.5133097,
#    't_run': 1747777147.531114,
#    't_cleanup': 1747777147.6584473,
#    't_inactive': 1747777147.660635,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 190956326354944,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777147.4959354,
#    't_depend': 1747777147.5132535,
#    't_run': 1747777147.530212,
#    't_cleanup': 1747777147.6568437,
#    't_inactive': 1747777147.6591,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 190297149538308,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777108.2059915,
#    't_depend': 1747777108.2225747,
#    't_run': 1747777108.2419765,
#    't_cleanup': 1747777111.4316046,
#    't_inactive': 1747777111.4366834,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 190297149538309,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777108.2061796,
#    't_depend': 1747777108.2226217,
#    't_run': 1747777108.242036,
#    't_cleanup': 1747777111.428525,
#    't_inactive': 1747777111.4343133,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 190297166315521,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777108.2064614,
#    't_depend': 1747777108.222717,
#    't_run': 1747777108.242151,
#    't_cleanup': 1747777111.4284403,
#    't_inactive': 1747777111.4341881,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 190297166315520,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777108.2063487,
#    't_depend': 1747777108.2226696,
#    't_run': 1747777108.2420862,
#    't_cleanup': 1747777111.4283748,
#    't_inactive': 1747777111.434077,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 190297149538307,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777108.2058723,
#    't_depend': 1747777108.2225273,
#    't_run': 1747777108.2419233,
#    't_cleanup': 1747777111.4281857,
#    't_inactive': 1747777111.4314618,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 190297149538306,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777108.2056558,
#    't_depend': 1747777108.2224772,
#    't_run': 1747777108.2418714,
#    't_cleanup': 1747777111.425981,
#    't_inactive': 1747777111.4293969,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 190297132761089,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777108.2049587,
#    't_depend': 1747777108.2223263,
#    't_run': 1747777108.2405334,
#    't_cleanup': 1747777111.4226136,
#    't_inactive': 1747777111.4274936,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 190297149538305,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777108.2054348,
#    't_depend': 1747777108.2224293,
#    't_run': 1747777108.2418165,
#    't_cleanup': 1747777111.4223645,
#    't_inactive': 1747777111.4273622,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 190297132761088,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777108.20494,
#    't_depend': 1747777108.2222419,
#    't_run': 1747777108.2394493,
#    't_cleanup': 1747777111.4221845,
#    't_inactive': 1747777111.426761,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 190297149538304,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747777108.205343,
#    't_depend': 1747777108.2223802,
#    't_run': 1747777108.2417397,
#    't_cleanup': 1747777111.4211514,
#    't_inactive': 1747777111.425742,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 183698704039936,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747776714.906515,
#    't_depend': 1747776714.9204206,
#    't_run': 1747776714.936302,
#    't_cleanup': 1747776718.9350698,
#    't_inactive': 1747776718.9372873,
#    'state': 64,
#    'name': 'flux',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 10,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'annotations': {'user': {'uri': 'ssh://248eca26e3ad/tmp/flux-CmxLDb/local-0'}},
#    'waitstatus': 0},
#   {'id': 183067226406912,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747776677.2661977,
#    't_depend': 1747776677.2795277,
#    't_run': 1747776677.294551,
#    't_cleanup': 1747776706.080117,
#    't_inactive': 1747776706.0840886,
#    'state': 64,
#    'name': 'flux',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 10,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': False,
#    'exception_occurred': False,
#    'result': 2,
#    'expiration': 9223372036.0,
#    'annotations': {'user': {'uri': 'ssh://248eca26e3ad/tmp/flux-dNraB9/local-0'}},
#    'waitstatus': 33024},
#   {'id': 165732839063552,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747775644.0516522,
#    't_depend': 1747775644.0685194,
#    't_run': 1747775644.08567,
#    't_cleanup': 1747776675.3021905,
#    't_inactive': 1747776675.317112,
#    'state': 64,
#    'name': 'sleep',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch1',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'cancel',
#    'exception_severity': 0,
#    'exception_note': '',
#    'result': 4,
#    'expiration': 9223372036.0,
#    'waitstatus': 36608},
#   {'id': 182728964177920,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747776657.1041503,
#    't_depend': 1747776657.118402,
#    't_run': 1747776657.1333654,
#    't_cleanup': 1747776671.0412173,
#    't_inactive': 1747776671.044392,
#    'state': 64,
#    'name': 'flux',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 10,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': '248eca26e3ad',
#    'success': False,
#    'exception_occurred': False,
#    'result': 2,
#    'expiration': 9223372036.0,
#    'annotations': {'user': {'uri': 'ssh://248eca26e3ad/tmp/flux-e8jqZM/local-0'}},
#    'waitstatus': 34304},
#   {'id': 174358358130688,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747776158.175425,
#    't_depend': 1747776158.1906004,
#    't_run': 1747776158.2071671,
#    't_cleanup': 1747776158.3321834,
#    't_inactive': 1747776158.3344698,
#    'state': 64,
#    'name': 'env',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 173066160177152,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747776081.1536293,
#    't_depend': 1747776081.1698885,
#    't_run': 1747776081.1842337,
#    't_cleanup': 1747776096.3295138,
#    't_inactive': 1747776096.3344746,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 172694460956672,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747776058.9982264,
#    't_depend': 1747776059.0135186,
#    't_run': 1747776059.0302718,
#    't_cleanup': 1747776064.1709514,
#    't_inactive': 1747776064.174247,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 171149698793472,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747775966.9232278,
#    't_depend': 1747775966.9375908,
#    't_run': 1747775966.951468,
#    't_cleanup': 1747775972.0897667,
#    't_inactive': 1747775972.0926838,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 170785834532864,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747775945.234906,
#    't_depend': 1747775945.247409,
#    't_run': 1747775945.2632897,
#    't_cleanup': 1747775950.4072144,
#    't_inactive': 1747775950.4111743,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 170589138452480,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747775933.5113845,
#    't_depend': 1747775933.5259855,
#    't_run': 1747775933.542969,
#    't_cleanup': 1747775933.6654587,
#    't_inactive': 1747775933.6675327,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 167688659795968,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747775760.6293519,
#    't_depend': 1747775760.6452029,
#    't_cleanup': 1747775760.6581626,
#    't_inactive': 1747775760.658216,
#    'state': 64,
#    'name': 'hello',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch1',
#    'ntasks': 16,
#    'ncores': 16,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 167343284027392,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747775740.042064,
#    't_depend': 1747775740.0561168,
#    't_run': 1747775740.0714824,
#    't_cleanup': 1747775743.754644,
#    't_inactive': 1747775743.756645,
#    'state': 64,
#    'name': 'flux',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 10,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'annotations': {'user': {'uri': 'ssh://248eca26e3ad/tmp/flux-BeAjle/local-0'}},
#    'waitstatus': 0},
#   {'id': 165469621321729,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747775628.3629363,
#    't_depend': 1747775628.3781662,
#    't_run': 1747775628.3982837,
#    't_cleanup': 1747775629.6268065,
#    't_inactive': 1747775629.6311555,
#    'state': 64,
#    'name': 'bash',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch1',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 165469604544513,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747775628.3621285,
#    't_depend': 1747775628.3779426,
#    't_run': 1747775628.3975832,
#    't_cleanup': 1747775629.62144,
#    't_inactive': 1747775629.6241956,
#    'state': 64,
#    'name': 'bash',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch1',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 165469621321728,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747775628.3627217,
#    't_depend': 1747775628.378113,
#    't_run': 1747775628.3977919,
#    't_cleanup': 1747775629.6177585,
#    't_inactive': 1747775629.6229587,
#    'state': 64,
#    'name': 'bash',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch1',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 165469604544512,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747775628.3618646,
#    't_depend': 1747775628.377885,
#    't_run': 1747775628.3975146,
#    't_cleanup': 1747775629.6176934,
#    't_inactive': 1747775629.6228528,
#    'state': 64,
#    'name': 'bash',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch1',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 165469604544514,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747775628.3623283,
#    't_depend': 1747775628.378002,
#    't_run': 1747775628.3976583,
#    't_cleanup': 1747775629.6176026,
#    't_inactive': 1747775629.6227539,
#    'state': 64,
#    'name': 'bash',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch1',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 165469587767297,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747775628.3615263,
#    't_depend': 1747775628.3778265,
#    't_run': 1747775628.3964186,
#    't_cleanup': 1747775629.6174576,
#    't_inactive': 1747775629.6226277,
#    'state': 64,
#    'name': 'bash',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch1',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 165469604544515,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747775628.3625362,
#    't_depend': 1747775628.3780587,
#    't_run': 1747775628.397735,
#    't_cleanup': 1747775629.6173718,
#    't_inactive': 1747775629.6219683,
#    'state': 64,
#    'name': 'bash',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch1',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 165469587767296,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747775628.3614836,
#    't_depend': 1747775628.3777628,
#    't_run': 1747775628.3953032,
#    't_cleanup': 1747775629.6168802,
#    't_inactive': 1747775629.62077,
#    'state': 64,
#    'name': 'bash',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch1',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 162574310047744,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747775455.788424,
#    't_depend': 1747775455.8012242,
#    't_run': 1747775455.8157346,
#    't_cleanup': 1747775455.9403136,
#    't_inactive': 1747775455.9421782,
#    'state': 64,
#    'name': 'hostname',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch1',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 131937268137984,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747773425.7871585,
#    't_depend': 1747773425.8017411,
#    't_run': 1747773425.817135,
#    't_cleanup': 1747773425.9445214,
#    't_inactive': 1747773425.9467776,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 130832488464387,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747773359.9370806,
#    't_depend': 1747773359.9545357,
#    't_run': 1747773361.7008915,
#    't_cleanup': 1747773361.9886436,
#    't_inactive': 1747773361.9907742,
#    'state': 64,
#    'name': 'sleep',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 130832471687169,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747773359.9357357,
#    't_depend': 1747773359.954157,
#    't_run': 1747773361.6345148,
#    't_cleanup': 1747773361.9768646,
#    't_inactive': 1747773361.9790668,
#    'state': 64,
#    'name': 'sleep',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 130832471687171,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747773359.936086,
#    't_depend': 1747773359.9542773,
#    't_run': 1747773361.680269,
#    't_cleanup': 1747773361.967635,
#    't_inactive': 1747773361.9703505,
#    'state': 64,
#    'name': 'sleep',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 130832471687168,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747773359.9355369,
#    't_depend': 1747773359.9541116,
#    't_run': 1747773361.6344342,
#    't_cleanup': 1747773361.9571104,
#    't_inactive': 1747773361.9597535,
#    'state': 64,
#    'name': 'sleep',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 130832488464386,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747773359.9368908,
#    't_depend': 1747773359.9544892,
#    't_run': 1747773361.7008095,
#    't_cleanup': 1747773361.954061,
#    't_inactive': 1747773361.9562867,
#    'state': 64,
#    'name': 'sleep',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 130832488464384,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747773359.9364626,
#    't_depend': 1747773359.9543757,
#    't_run': 1747773361.6891265,
#    't_cleanup': 1747773361.9496443,
#    't_inactive': 1747773361.9516425,
#    'state': 64,
#    'name': 'sleep',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 130832488464385,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747773359.9366844,
#    't_depend': 1747773359.9544373,
#    't_run': 1747773361.6893306,
#    't_cleanup': 1747773361.9458096,
#    't_inactive': 1747773361.9484036,
#    'state': 64,
#    'name': 'sleep',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 130832471687172,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747773359.9362607,
#    't_depend': 1747773359.9543247,
#    't_run': 1747773361.6882033,
#    't_cleanup': 1747773361.940736,
#    't_inactive': 1747773361.9430397,
#    'state': 64,
#    'name': 'sleep',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 130832471687170,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747773359.9359117,
#    't_depend': 1747773359.9542217,
#    't_run': 1747773361.6621807,
#    't_cleanup': 1747773361.932492,
#    't_inactive': 1747773361.9353592,
#    'state': 64,
#    'name': 'sleep',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 130832454909955,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747773359.9351547,
#    't_depend': 1747773359.9540627,
#    't_run': 1747773361.620498,
#    't_cleanup': 1747773361.9073188,
#    't_inactive': 1747773361.9118543,
#    'state': 64,
#    'name': 'sleep',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 130832454909954,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747773359.9348712,
#    't_depend': 1747773359.9540117,
#    't_run': 1747773361.3640258,
#    't_cleanup': 1747773361.8481987,
#    't_inactive': 1747773361.856456,
#    'state': 64,
#    'name': 'sleep',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 130832454909953,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747773359.9346995,
#    't_depend': 1747773359.9539657,
#    't_run': 1747773361.3196929,
#    't_cleanup': 1747773361.8082862,
#    't_inactive': 1747773361.8174973,
#    'state': 64,
#    'name': 'sleep',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 130832421355521,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747773359.9327714,
#    't_depend': 1747773359.953363,
#    't_run': 1747773360.9581296,
#    't_cleanup': 1747773361.7834923,
#    't_inactive': 1747773361.8058894,
#    'state': 64,
#    'name': 'sleep',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 130832454909952,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747773359.9345145,
#    't_depend': 1747773359.9539201,
#    't_run': 1747773361.282282,
#    't_cleanup': 1747773361.7813447,
#    't_inactive': 1747773361.8028734,
#    'state': 64,
#    'name': 'sleep',
#    'cwd': '/home/jovyan/flux-tutorial-2024/flux-for-lc/ch2',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': '248eca26e3ad',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
# ...
#    'ncores': 15,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 13482187554816,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747766365.281869,
#    't_depend': 1747766365.295415,
#    't_cleanup': 1747766365.3108807,
#    't_inactive': 1747766365.3109334,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 15,
#    'ncores': 15,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 11695917367296,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747766258.811436,
#    't_depend': 1747766258.8239853,
#    't_cleanup': 1747766258.8374405,
#    't_inactive': 1747766258.837485,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 15,
#    'ncores': 15,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 6436729913344,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765945.3377113,
#    't_depend': 1747765945.3509812,
#    't_cleanup': 1747765945.364162,
#    't_inactive': 1747765945.3642454,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 15,
#    'ncores': 15,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 6165022900224,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765929.14233,
#    't_depend': 1747765929.1552963,
#    't_cleanup': 1747765929.1682792,
#    't_inactive': 1747765929.1683292,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 15,
#    'ncores': 15,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 5931198840832,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765915.2022367,
#    't_depend': 1747765915.217326,
#    't_cleanup': 1747765915.231948,
#    't_inactive': 1747765915.2319944,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 15,
#    'ncores': 15,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 5481217130496,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765888.3813,
#    't_depend': 1747765888.3936374,
#    't_cleanup': 1747765888.407056,
#    't_inactive': 1747765888.4071155,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 15,
#    'ncores': 15,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 4743321616384,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765844.402502,
#    't_depend': 1747765844.4159951,
#    't_cleanup': 1747765844.42944,
#    't_inactive': 1747765844.4294968,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 15,
#    'ncores': 15,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 4664770691072,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765839.720088,
#    't_depend': 1747765839.7347019,
#    't_cleanup': 1747765839.7476995,
#    't_inactive': 1747765839.7477448,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 15,
#    'ncores': 15,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 3237935579136,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765754.6735988,
#    't_depend': 1747765754.6860895,
#    't_cleanup': 1747765754.6983857,
#    't_inactive': 1747765754.698456,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 15,
#    'ncores': 15,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 2900780646400,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765734.5780795,
#    't_depend': 1747765734.5900135,
#    't_cleanup': 1747765734.60224,
#    't_inactive': 1747765734.602296,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 15,
#    'ncores': 15,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 2383203532800,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765703.726892,
#    't_depend': 1747765703.7408543,
#    't_cleanup': 1747765703.7554796,
#    't_inactive': 1747765703.7555299,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 15,
#    'ncores': 15,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 670132338688,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765601.6204145,
#    't_depend': 1747765601.6317334,
#    't_cleanup': 1747765601.6450317,
#    't_inactive': 1747765601.6450877,
#    'state': 64,
#    'name': 'hello',
#    'ntasks': 16,
#    'ncores': 16,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 667649310720,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765601.4723525,
#    't_depend': 1747765601.4839249,
#    't_run': 1747765601.513605,
#    't_cleanup': 1747765601.6177275,
#    't_inactive': 1747765601.6236956,
#    'state': 64,
#    'name': 'hello',
#    'ntasks': 10,
#    'ncores': 10,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': '248eca26e3ad',
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'exec',
#    'exception_severity': 0,
#    'exception_note': 'task 0 (host 248eca26e3ad): start failed: ../ch1/hello: No such file or directory',
#    'result': 2,
#    'expiration': 9223372036.0,
#    'waitstatus': 32512},
#   {'id': 669712908288,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765601.5951424,
#    't_depend': 1747765601.6074128,
#    't_cleanup': 1747765601.6196833,
#    't_inactive': 1747765601.6197307,
#    'state': 64,
#    'name': 'hello',
#    'ntasks': 15,
#    'ncores': 15,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 667145994240,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765601.442881,
#    't_depend': 1747765601.4592233,
#    't_run': 1747765601.485177,
#    't_cleanup': 1747765601.5925233,
#    't_inactive': 1747765601.5992777,
#    'state': 64,
#    'name': 'hello',
#    'ntasks': 9,
#    'ncores': 9,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'exec',
#    'exception_severity': 0,
#    'exception_note': 'task 0 (host 248eca26e3ad): start failed: ../ch1/hello: No such file or directory',
#    'result': 2,
#    'expiration': 9223372036.0,
#    'waitstatus': 32512},
#   {'id': 669293477888,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765601.5700548,
#    't_depend': 1747765601.581893,
#    't_cleanup': 1747765601.5944624,
#    't_inactive': 1747765601.5945518,
#    'state': 64,
#    'name': 'hello',
#    'ntasks': 14,
#    'ncores': 14,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 668874047488,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765601.5457916,
#    't_depend': 1747765601.5569253,
#    't_cleanup': 1747765601.5693095,
#    't_inactive': 1747765601.5693572,
#    'state': 64,
#    'name': 'hello',
#    'ntasks': 13,
#    'ncores': 13,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 666693009408,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765601.4149437,
#    't_depend': 1747765601.4285848,
#    't_run': 1747765601.461692,
#    't_cleanup': 1747765601.5617905,
#    't_inactive': 1747765601.567234,
#    'state': 64,
#    'name': 'hello',
#    'ntasks': 8,
#    'ncores': 8,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': '248eca26e3ad',
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'exec',
#    'exception_severity': 0,
#    'exception_note': 'task 0 (host 248eca26e3ad): start failed: ../ch1/hello: No such file or directory',
#    'result': 2,
#    'expiration': 9223372036.0,
#    'waitstatus': 32512},
#   {'id': 668454617088,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765601.5201752,
#    't_depend': 1747765601.5320797,
#    't_cleanup': 1747765601.5451248,
#    't_inactive': 1747765601.545155,
#    'state': 64,
#    'name': 'hello',
#    'ntasks': 12,
#    'ncores': 12,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 666206470144,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765601.3867164,
#    't_depend': 1747765601.399216,
#    't_run': 1747765601.415568,
#    't_cleanup': 1747765601.5285604,
#    't_inactive': 1747765601.5346212,
#    'state': 64,
#    'name': 'hello',
#    'ntasks': 7,
#    'ncores': 7,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': '248eca26e3ad',
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'exec',
#    'exception_severity': 0,
#    'exception_note': 'task 0 (host 248eca26e3ad): start failed: ../ch1/hello: No such file or directory',
#    'result': 2,
#    'expiration': 9223372036.0,
#    'waitstatus': 32512},
#   {'id': 668018409472,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765601.4945104,
#    't_depend': 1747765601.5059557,
#    't_cleanup': 1747765601.5197456,
#    't_inactive': 1747765601.5198066,
#    'state': 64,
#    'name': 'hello',
#    'ntasks': 11,
#    'ncores': 11,
#    'duration': 0.0,
#    'nnodes': 1,
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'alloc',
#    'exception_severity': 0,
#    'exception_note': 'alloc denied due to type="unsatisfiable"',
#    'result': 2},
#   {'id': 665787039744,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765601.3615768,
#    't_depend': 1747765601.3731246,
#    't_run': 1747765601.3871927,
#    't_cleanup': 1747765601.5065305,
#    't_inactive': 1747765601.5118055,
#    'state': 64,
#    'name': 'hello',
#    'ntasks': 6,
#    'ncores': 6,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': '248eca26e3ad',
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'exec',
#    'exception_severity': 0,
#    'exception_note': 'task 0 (host 248eca26e3ad): start failed: ../ch1/hello: No such file or directory',
#    'result': 2,
#    'expiration': 9223372036.0,
#    'waitstatus': 32512},
#   {'id': 665132728320,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765601.3225179,
#    't_depend': 1747765601.3476303,
#    't_run': 1747765601.3619525,
#    't_cleanup': 1747765601.477181,
#    't_inactive': 1747765601.4832232,
#    'state': 64,
#    'name': 'hello',
#    'ntasks': 5,
#    'ncores': 5,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'exec',
#    'exception_severity': 0,
#    'exception_note': 'task 0 (host 248eca26e3ad): start failed: ../ch1/hello: No such file or directory',
#    'result': 2,
#    'expiration': 9223372036.0,
#    'waitstatus': 32512},
#   {'id': 664713297920,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765601.297478,
#    't_depend': 1747765601.3095367,
#    't_run': 1747765601.3227992,
#    't_cleanup': 1747765601.4498818,
#    't_inactive': 1747765601.4600124,
#    'state': 64,
#    'name': 'hello',
#    'ntasks': 4,
#    'ncores': 4,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': '248eca26e3ad',
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'exec',
#    'exception_severity': 0,
#    'exception_note': 'task 0 (host 248eca26e3ad): start failed: ../ch1/hello: No such file or directory',
#    'result': 2,
#    'expiration': 9223372036.0,
#    'waitstatus': 32512},
#   {'id': 663857659904,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765601.2464645,
#    't_depend': 1747765601.2585952,
#    't_run': 1747765601.2743251,
#    't_cleanup': 1747765601.4289699,
#    't_inactive': 1747765601.4434998,
#    'state': 64,
#    'name': 'hello',
#    'ntasks': 2,
#    'ncores': 2,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': '248eca26e3ad',
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'exec',
#    'exception_severity': 0,
#    'exception_note': 'task 0 (host 248eca26e3ad): start failed: ../ch1/hello: No such file or directory',
#    'result': 2,
#    'expiration': 9223372036.0,
#    'waitstatus': 32512},
#   {'id': 663320788992,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765601.2148185,
#    't_depend': 1747765601.232404,
#    't_run': 1747765601.2736952,
#    't_cleanup': 1747765601.4291632,
#    't_inactive': 1747765601.44244,
#    'state': 64,
#    'name': 'hello',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': '248eca26e3ad',
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'exec',
#    'exception_severity': 0,
#    'exception_note': 'task 0 (host 248eca26e3ad): start failed: ../ch1/hello: No such file or directory',
#    'result': 2,
#    'expiration': 9223372036.0,
#    'waitstatus': 32512},
#   {'id': 664277090304,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747765601.2717211,
#    't_depend': 1747765601.28361,
#    't_run': 1747765601.2975323,
#    't_cleanup': 1747765601.4222524,
#    't_inactive': 1747765601.4408727,
#    'state': 64,
#    'name': 'hello',
#    'ntasks': 3,
#    'ncores': 3,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': '248eca26e3ad',
#    'success': False,
#    'exception_occurred': True,
#    'exception_type': 'exec',
#    'exception_severity': 0,
#    'exception_note': 'task 0 (host 248eca26e3ad): start failed: ../ch1/hello: No such file or directory',
#    'result': 2,
#    'expiration': 9223372036.0,
#    'waitstatus': 32512}]}

# %%
# get an allocation, split into two instances, submit jobs to that instance
# things to set in the jobspec initializer versus with jobspec methods
# how to specify things in the python script as

# %%
jobspec.config.update("resource.rediscover", "true")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_215/3045981699.py in <cell line: 1>()
# ----> 1 jobspec.config.update("resource.rediscover", "true")
#
# AttributeError: 'JobspecV1' object has no attribute 'config'
